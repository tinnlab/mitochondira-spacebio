# %% [markdown]
# ### This code computes the pearson's correlation for metabolic processes in samples exposed to cosmic radiations in-flights, post-flight and a combination of both. Bonferroni corrections were applied to identify false positives.

# %%
import pandas as pd
from scipy.stats import pearsonr
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../../All_strain.xlsx')
df
# Out:
#       Organ  Radio_Sensitivity  mGy_Absorbed  ISS_Days  Return_Days Sex  \
# 0    Spleen                  1        8.9700     39.00            1   M
# 1    Thymus                  1        3.1500     13.00            1   F
# 2    Thymus                  1        8.9700     39.00            1   M
# 3    Muscle                  4        5.0875     22.50            0   M
# 4     Liver                  3        4.6600     12.76            1   F
# ..      ...                ...           ...       ...          ...  ..
# 531    Skin                  2       21.9530     75.00            0   F
# 532  Muscle                  4       30.0700     29.85            1   M
# 533  Muscle                  4       30.0700     29.85            1   M
# 534  Muscle                  4       30.0700     29.85            1   M
# 535  Muscle                  4       30.0700     29.85            1   M
#
#       Strain   Age  Mission  MT_Central_Dogma  ...  mtDNA_Activated  \
# ...

# %% [markdown]
# ### Inflight vs Post-flight

# %%
# In-flight
di = df[df['Return_Days'] < 1]
di
# Out:
#       Organ  Radio_Sensitivity  mGy_Absorbed  ISS_Days  Return_Days Sex  \
# 3    Muscle                  4        5.0875      22.5            0   M
# 14    Liver                  3        6.4700      22.5            0   F
# 15   Kidney                  3        6.4625      25.0            0   F
# 16   Kidney                  3        6.4625      25.0            0   F
# 17   Kidney                  3       19.3875      75.0            0   F
# ..      ...                ...           ...       ...          ...  ..
# 527   Heart                  3       17.8450      55.0            0   F
# 528  Kidney                  3       19.3875      75.0            0   F
# 529  Kidney                  3       19.3875      75.0            0   F
# 530    Skin                  2       21.9528      75.0            0   F
# 531    Skin                  2       21.9530      75.0            0   F
#
#       Strain   Age       Mission  MT_Central_Dogma  ...  mtDNA_Activated  \
# ...

# %%
# Post-flight
dp = df[df['Return_Days'] > 0]
dp
# Out:
#       Organ  Radio_Sensitivity  mGy_Absorbed  ISS_Days  Return_Days Sex  \
# 0    Spleen                  1         8.970     39.00            1   M
# 1    Thymus                  1         3.150     13.00            1   F
# 2    Thymus                  1         8.970     39.00            1   M
# 4     Liver                  3         4.660     12.76            1   F
# 5     Liver                  3         4.660     12.76            1   F
# ..      ...                ...           ...       ...          ...  ..
# 518  Muscle                  4        13.135     37.00            1   M
# 532  Muscle                  4        30.070     29.85            1   M
# 533  Muscle                  4        30.070     29.85            1   M
# 534  Muscle                  4        30.070     29.85            1   M
# 535  Muscle                  4        30.070     29.85            1   M
#
#       Strain   Age  Mission  MT_Central_Dogma  ...  mtDNA_Activated  \
# ...

# %% [markdown]
# ### All Samples

# %%
### Pearson correlation of Metabolic process against the amount of amount of radiation absorbed
### Correlation for all samples

ref_col_name = df.columns[2]  # Column 3 - amount of radiation absorbed (mGy_Absorbed)
target_cols = df.columns[21:37] # Columns 22 to 37

results = []

# Step 1: Pearson correlations
for col in target_cols:
    x = df[ref_col_name]
    y = df[col]

    valid = x.notna() & y.notna()
    x_valid = x[valid]
    y_valid = y[valid]

    if len(x_valid) >= 2:
        r, p = pearsonr(x_valid, y_valid)
        results.append({'Processes': col, 'correlation': r, 'p_value': p})
    else:
        results.append({'Processes': col, 'correlation': None, 'p_value': None})

results_df = pd.DataFrame(results)

# Step 2: Adjust p-values (Bonferroni correction)
results_df = results_df.dropna(subset=['p_value'])
adjusted = multipletests(results_df['p_value'], method='bonferroni')
results_df['p_value_adj'] = adjusted[1]
results_df['significant'] = adjusted[0]

# Step 3: Sort by absolute correlation
results_df['abs_corr'] = results_df['correlation'].abs()
results_df_sorted = results_df.sort_values(by='abs_corr', ascending=False)

results_df_sorted.to_csv('Correlation_Metabolic_vs_Radiation_AllSample.csv', index=False)

# Step 4: Plot top N correlations
top_n = 20
top_results = results_df_sorted.head(top_n)

top_results
# Out:
#                   Processes  correlation       p_value   p_value_adj  \
# 7      Fatty_Acid_Oxidation    -0.241590  1.476411e-08  2.362258e-07
# 2                      mTOR     0.238243  2.357936e-08  3.772698e-07
# 3                Metabolism    -0.158919  2.206142e-04  3.529827e-03
# 4                Glycolysis     0.141903  9.866268e-04  1.578603e-02
# 14               Peroxisome    -0.128447  2.890252e-03  4.624402e-02
# 5                 TCA_Cycle    -0.105601  1.444570e-02  2.311312e-01
# 1                     HIF1a     0.096734  2.511884e-02  4.019014e-01
# 0                HIF1a_mTOR    -0.070060  1.051857e-01  1.000000e+00
# 15     Antioxidant_Defenses     0.069092  1.100945e-01  1.000000e+00
# 9                Urea_Cycle    -0.038780  3.702158e-01  1.000000e+00
# 13     Folate_Single_Carbon     0.029673  4.930145e-01  1.000000e+00
# 6      Fatty_Acid_Synthesis    -0.023805  5.823763e-01  1.000000e+00
# 8          ATP_NAD_Carriers    -0.021966  6.118622e-01  1.000000e+00
# ...

# %%
drop= ['Metabolism']
top_results1 = top_results[~top_results['Processes'].isin(drop)]

top_results1

# Step 4: Filter only significant results
significant_results = top_results1[top_results1['significant']]
significant_results

# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 7.5))
# fig, ax = plt.subplots(figsize=(10, 4.5))
bars = ax.barh(top_results1['Processes'], top_results1['correlation'], color=['green' if s else 'gray' for s in top_results1['significant']])
# bars = ax.barh(significant_results['Processes'], significant_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
plt.xlabel("Pearson Correlation with Amount Radiation Absorbed", fontsize = 14.0)

plt.axvline(x=0, color='black', linewidth=0.8)
plt.tick_params(labelsize=12, pad=1)

ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
plt.savefig('Correlation_Metabolic_vs_Radiation_AllSample.tiff',format='tiff', dpi=300, transparent=False)
# plt.savefig('Correlation_Metabolic_vs_Radiation_AllSample_sig.tiff',format='tiff', dpi=300, transparent=False)
plt.show()

# %%
### Pearson correlation of Metabolic processes against the number of days at ISS
### Correlation for all samples

ref_col_name = df.columns[3]  # Column 4 - Days in ISS
target_cols = df.columns[21:37] # Columns 22 to 37

results = []

# Step 1: Pearson correlations
for col in target_cols:
    x = df[ref_col_name]
    y = df[col]

    valid = x.notna() & y.notna()
    x_valid = x[valid]
    y_valid = y[valid]

    if len(x_valid) >= 2:
        r, p = pearsonr(x_valid, y_valid)
        results.append({'Processes': col, 'correlation': r, 'p_value': p})
    else:
        results.append({'Processes': col, 'correlation': None, 'p_value': None})

results_df = pd.DataFrame(results)

# Step 2: Adjust p-values (Bonferroni correction)
results_df = results_df.dropna(subset=['p_value'])
adjusted = multipletests(results_df['p_value'], method='bonferroni')
results_df['p_value_adj'] = adjusted[1]
results_df['significant'] = adjusted[0]

# Step 3: Sort by absolute correlation
results_df['abs_corr'] = results_df['correlation'].abs()
results_df_sorted = results_df.sort_values(by='abs_corr', ascending=False)

results_df_sorted.to_csv('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_AllSample.csv', index=False)

# Step 4: Plot top N correlations
top_n = 20
drop= ['Metabolism']
top_results = results_df_sorted.head(top_n)
top_results = top_results[~top_results['Processes'].isin(drop)]

significant_results = top_results[top_results['significant']]

# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 7.5))
# fig, ax = plt.subplots(figsize=(8, 4))
bars = ax.barh(top_results['Processes'], top_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
# bars = ax.barh(significant_results['Processes'], significant_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])

plt.xlabel("Pearson Correlation with Time (Days) at ISS", fontsize = 14.0)

plt.axvline(x=0, color='black', linewidth=0.8)
plt.tick_params(labelsize=12, pad=1)

ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
plt.savefig('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_AllSample.tiff',format='tiff', dpi=300, transparent=False)
# plt.savefig('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_AllSample_sig.tiff',format='tiff', dpi=300, transparent=False)
plt.show()

# %% [markdown]
# ### In-flight Samples

# %%
### Pearson correlation of Metabolic processes against the amount of amount of radiation absorbed
### Correlation for In-flight samples

ref_col_name = di.columns[2]  # Column 3 - amount of radiation absorbed (mGy_Absorbed)
target_cols = di.columns[21:37] # Columns 22 to 37

results = []

# Step 1: Pearson correlations
for col in target_cols:
    x = di[ref_col_name]
    y = di[col]

    valid = x.notna() & y.notna()
    x_valid = x[valid]
    y_valid = y[valid]

    if len(x_valid) >= 2:
        r, p = pearsonr(x_valid, y_valid)
        results.append({'Processes': col, 'correlation': r, 'p_value': p})
    else:
        results.append({'Processes': col, 'correlation': None, 'p_value': None})

results_df = pd.DataFrame(results)

# Step 2: Adjust p-values (Bonferroni correction)
results_df = results_df.dropna(subset=['p_value'])
adjusted = multipletests(results_df['p_value'], method='bonferroni')
results_df['p_value_adj'] = adjusted[1]
results_df['significant'] = adjusted[0]

# Step 3: Sort by absolute correlation
results_df['abs_corr'] = results_df['correlation'].abs()
results_df_sorted = results_df.sort_values(by='abs_corr', ascending=False)

results_df_sorted.to_csv('Correlation_Metabolic_vs_Radiation_Inflight.csv', index=False)

# Step 4: Plot top N correlations
top_n = 20
drop= ['Metabolism']
top_results = results_df_sorted.head(top_n)
top_results = top_results[~top_results['Processes'].isin(drop)]

significant_results = top_results[top_results['significant']]


# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 7))
# fig, ax = plt.subplots(figsize=(10, 4.5))
bars = ax.barh(top_results['Processes'], top_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
# bars = ax.barh(significant_results['Processes'], significant_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
plt.xlabel("Pearson Correlation with Amount Radiation Absorbed", fontsize = 14.0)

plt.axvline(x=0, color='black', linewidth=0.8)
plt.tick_params(labelsize=12, pad=1)

ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
plt.savefig('Correlation_Metabolic_vs_Radiation_Inflight.tiff',format='tiff', dpi=300, transparent=False)
# plt.savefig('Correlation_Metabolic_vs_Radiation_Inflight_sig.tiff',format='tiff', dpi=300, transparent=False)
plt.show()

# %%
### Pearson correlation of Metabolic processes against the number of days at ISS
### Correlation for In-flight samples

ref_col_name = dp.columns[3]  # Column 4 - Days in ISS
target_cols = dp.columns[21:37] # Columns 22 to 37

results = []

# Step 1: Pearson correlations
for col in target_cols:
    x = dp[ref_col_name]
    y = dp[col]

    valid = x.notna() & y.notna()
    x_valid = x[valid]
    y_valid = y[valid]

    if len(x_valid) >= 2:
        r, p = pearsonr(x_valid, y_valid)
        results.append({'Processes': col, 'correlation': r, 'p_value': p})
    else:
        results.append({'Processes': col, 'correlation': None, 'p_value': None})

results_df = pd.DataFrame(results)

# Step 2: Adjust p-values (Bonferroni correction)
results_df = results_df.dropna(subset=['p_value'])
adjusted = multipletests(results_df['p_value'], method='bonferroni')
results_df['p_value_adj'] = adjusted[1]
results_df['significant'] = adjusted[0]

# Step 3: Sort by absolute correlation
results_df['abs_corr'] = results_df['correlation'].abs()
results_df_sorted = results_df.sort_values(by='abs_corr', ascending=False)

results_df_sorted.to_csv('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_Inflight.csv', index=False)

# Step 4: Plot top N correlations
top_n = 20
drop= ['Metabolism',]
top_results = results_df_sorted.head(top_n)
top_results = top_results[~top_results['Processes'].isin(drop)]

significant_results = top_results[top_results['significant']]

# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 7))
# fig, ax = plt.subplots(figsize=(10, 4.5))
bars = ax.barh(top_results['Processes'], top_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
# bars = ax.barh(significant_results['Processes'], significant_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
plt.xlabel("Pearson Correlation with Time (Days) at ISS", fontsize = 14.0)

plt.axvline(x=0, color='black', linewidth=0.8)
plt.tick_params(labelsize=12, pad=1)

ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
plt.savefig('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_Inflight.tiff',format='tiff', dpi=300, transparent=False)
# plt.savefig('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_Inflight_sig.tiff',format='tiff', dpi=300, transparent=False)
plt.show()

# %% [markdown]
# ### Post-flight

# %%
### Pearson correlation of Metabolic processes against the amount of amount of radiation absorbed
### Correlation for Post-flight samples

ref_col_name = dp.columns[2]  # Column 3 - amount of radiation absorbed (mGy_Absorbed)
target_cols = dp.columns[21:37] # Columns 22 to 37

results = []

# Step 1: Pearson correlations
for col in target_cols:
    x = dp[ref_col_name]
    y = dp[col]

    valid = x.notna() & y.notna()
    x_valid = x[valid]
    y_valid = y[valid]

    if len(x_valid) >= 2:
        r, p = pearsonr(x_valid, y_valid)
        results.append({'Processes': col, 'correlation': r, 'p_value': p})
    else:
        results.append({'Processes': col, 'correlation': None, 'p_value': None})

results_df = pd.DataFrame(results)

# Step 2: Adjust p-values (Bonferroni correction)
results_df = results_df.dropna(subset=['p_value'])
adjusted = multipletests(results_df['p_value'], method='bonferroni')
results_df['p_value_adj'] = adjusted[1]
results_df['significant'] = adjusted[0]

# Step 3: Sort by absolute correlation
results_df['abs_corr'] = results_df['correlation'].abs()
results_df_sorted = results_df.sort_values(by='abs_corr', ascending=False)

results_df_sorted.to_csv('Correlation_Metabolic_vs_Radiation_Postflight.csv', index=False)

# Step 4: Plot top N correlations
top_n = 20
drop= ['Metabolism']
top_results = results_df_sorted.head(top_n)
top_results = top_results[~top_results['Processes'].isin(drop)]

significant_results = top_results[top_results['significant']]

# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots(figsize=(10, 7))
# fig, ax = plt.subplots(figsize=(10, 4.5))
bars = ax.barh(top_results['Processes'], top_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
# bars = ax.barh(significant_results['Processes'], significant_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
plt.xlabel("Pearson Correlation with Amount Radiation Absorbed", fontsize = 14.0)

plt.axvline(x=0, color='black', linewidth=0.8)
plt.tick_params(labelsize=12, pad=1)

ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
plt.savefig('Correlation_Metabolic_vs_Radiation_Postflight.tiff',format='tiff', dpi=300, transparent=False)
# plt.savefig('Correlation_Metabolic_vs_Radiation_Postflight_sig.tiff',format='tiff', dpi=300, transparent=False)
plt.show()

# %%
### Pearson correlation of Metabolic processes against the number of days at ISS
### Correlation for Post-flight samples

ref_col_name = dp.columns[3]  # Column 4 - Days in ISS
target_cols = dp.columns[21:37] # Columns 22 to 37

results = []

# Step 1: Pearson correlations
for col in target_cols:
    x = dp[ref_col_name]
    y = dp[col]

    valid = x.notna() & y.notna()
    x_valid = x[valid]
    y_valid = y[valid]

    if len(x_valid) >= 2:
        r, p = pearsonr(x_valid, y_valid)
        results.append({'Processes': col, 'correlation': r, 'p_value': p})
    else:
        results.append({'Processes': col, 'correlation': None, 'p_value': None})

results_df = pd.DataFrame(results)

# Step 2: Adjust p-values (Bonferroni correction)
results_df = results_df.dropna(subset=['p_value'])
adjusted = multipletests(results_df['p_value'], method='bonferroni')
results_df['p_value_adj'] = adjusted[1]
results_df['significant'] = adjusted[0]

# Step 3: Sort by absolute correlation
results_df['abs_corr'] = results_df['correlation'].abs()
results_df_sorted = results_df.sort_values(by='abs_corr', ascending=False)

results_df_sorted.to_csv('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_Postflight.csv', index=False)

significant_results = results_df_sorted[results_df_sorted['significant']]

# Step 4: Plot top N correlations
top_n = 20
drop= ['Metabolism']
top_results = results_df_sorted.head(top_n)
top_results = top_results[~top_results['Processes'].isin(drop)]

significant_results = top_results[top_results['significant']]

# plt.figure(figsize=(10, 6))
# fig, ax = plt.subplots(figsize=(10, 7))
fig, ax = plt.subplots(figsize=(10, 4.5))
# bars = ax.barh(top_results['Processes'], top_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
bars = ax.barh(significant_results['Processes'], significant_results['correlation'], color=['green' if s else 'gray' for s in top_results['significant']])
plt.xlabel("Pearson Correlation with Time (Days) at ISS", fontsize = 14.0)

plt.axvline(x=0, color='black', linewidth=0.8)
plt.tick_params(labelsize=12, pad=1)

ax.spines["top"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)
ax.spines["right"].set_linewidth(3)
ax.spines["bottom"].set_linewidth(3)

plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
# plt.savefig('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_Postflight.tiff',format='tiff', dpi=300, transparent=False)
plt.savefig('../Correlation_vs_ISS/Correlation_Metabolic_vs_ISS_Postflight_sig.tiff',format='tiff', dpi=300, transparent=False)
plt.show()
